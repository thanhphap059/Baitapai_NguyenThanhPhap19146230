# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhphap059/NguyenThanhPhap19146230/blob/main/FASHION_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nguyễn Thanh Pháp 19146230
# Khai báo và sử dụng các thư viện sau
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping
from sklearn.utils import validation 
from sklearn import preprocessing

# %%
# Sử dụng tập dữ liệu MNIST với bộ dữ liệu đã chia giữa phần train là 60000 và phần test là 10000
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
plt.imshow(x_train[0])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
for i in range(9):
  plt.subplot(330+i+1)
  plt.imshow(x_train[i])
plt.show()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
# Xử lý phần dữ liệu đã chia
x_train=x_train.reshape(60000,784)
x_test=x_test.reshape(10000,784)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
#x_train=x_train/255
#x_test=x_test/255
scaler=preprocessing.StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)

# %%
# Tạo mô hình
model=Sequential()
# Tạo lớp ẩn thứ nhất với 784 tín hiệu vào (784 hàng và 1 cột) và có 1024 tín hiệu ra sử dụng hàm relu
model.add(Dense(1024,activation='relu',input_shape=(784,)))
# Tạo lớp ẩn thứ hai với 1024 tín hiệu vào, 512 tín hiệu ra (lấy tín hiệu vào là tín hiệu ra của lớp 1)
model.add(Dense(512,activation='relu'))
# Tạo lớp ẩn thứ ba với 512tín hiệu vào, 512 tín hiệu ra (lấy tín hiệu vào là tín hiệu ra của lớp 2)
model.add(Dense(512,activation='relu'))
# Tạo lớp ẩn thứ tư với 512 tín hiệu vào, 10 tín hiệu ra
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              803840
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,596,426
# Trainable params: 1,596,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học 128 dữ liệu (batch_size), khi sai số không thay đổi trong 50 lần học thì sẽ dừng học ngay
history= model.fit(x_train, y_train, batch_size=128, epochs=500, verbose=1, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/500
# 375/375 [==============================] - 19s 46ms/step - loss: 0.5258 - accuracy: 0.8124 - val_loss: 0.3899 - val_accuracy: 0.8608
# Epoch 2/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.3704 - accuracy: 0.8668 - val_loss: 0.3563 - val_accuracy: 0.8730
# Epoch 3/500
# 375/375 [==============================] - 18s 48ms/step - loss: 0.3326 - accuracy: 0.8796 - val_loss: 0.4174 - val_accuracy: 0.8622
# Epoch 4/500
# 375/375 [==============================] - 18s 48ms/step - loss: 0.3098 - accuracy: 0.8885 - val_loss: 0.3996 - val_accuracy: 0.8752
# Epoch 5/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2952 - accuracy: 0.8956 - val_loss: 0.4318 - val_accuracy: 0.8801
# Epoch 6/500
# 375/375 [==============================] - 18s 47ms/step - loss: 0.2798 - accuracy: 0.9011 - val_loss: 0.4315 - val_accuracy: 0.8860
# Epoch 7/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.2725 - accuracy: 0.9043 - val_loss: 0.4640 - val_accuracy: 0.8767
# Epoch 8/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2631 - accuracy: 0.9090 - val_loss: 0.4342 - val_accuracy: 0.8831
# Epoch 9/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.2593 - accuracy: 0.9131 - val_loss: 0.4656 - val_accuracy: 0.8867
# Epoch 10/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.2409 - accuracy: 0.9168 - val_loss: 0.4684 - val_accuracy: 0.8870
# Epoch 11/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.2420 - accuracy: 0.9190 - val_loss: 0.4695 - val_accuracy: 0.8837
# Epoch 12/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2445 - accuracy: 0.9229 - val_loss: 0.4730 - val_accuracy: 0.8863
# Epoch 13/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.2415 - accuracy: 0.9258 - val_loss: 0.4804 - val_accuracy: 0.8912
# Epoch 14/500
# 375/375 [==============================] - 16s 43ms/step - loss: 0.2354 - accuracy: 0.9272 - val_loss: 0.5068 - val_accuracy: 0.8885
# Epoch 15/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2131 - accuracy: 0.9302 - val_loss: 0.5523 - val_accuracy: 0.8882
# Epoch 16/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2340 - accuracy: 0.9295 - val_loss: 0.5359 - val_accuracy: 0.8873
# Epoch 17/500
# 375/375 [==============================] - 16s 44ms/step - loss: 0.2415 - accuracy: 0.9342 - val_loss: 0.9060 - val_accuracy: 0.8723
# Epoch 18/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.2057 - accuracy: 0.9359 - val_loss: 0.6640 - val_accuracy: 0.8829
# Epoch 19/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2244 - accuracy: 0.9376 - val_loss: 0.5697 - val_accuracy: 0.8883
# Epoch 20/500
# 375/375 [==============================] - 16s 44ms/step - loss: 0.1943 - accuracy: 0.9385 - val_loss: 0.9425 - val_accuracy: 0.8887
# Epoch 21/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1937 - accuracy: 0.9420 - val_loss: 0.7672 - val_accuracy: 0.8836
# Epoch 22/500
# 375/375 [==============================] - 17s 47ms/step - loss: 0.1930 - accuracy: 0.9447 - val_loss: 0.8620 - val_accuracy: 0.8798
# Epoch 23/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2067 - accuracy: 0.9449 - val_loss: 1.0114 - val_accuracy: 0.8748
# Epoch 24/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1688 - accuracy: 0.9464 - val_loss: 0.8248 - val_accuracy: 0.8807
# Epoch 25/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.1918 - accuracy: 0.9482 - val_loss: 0.9900 - val_accuracy: 0.8816
# Epoch 26/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.1876 - accuracy: 0.9465 - val_loss: 0.7315 - val_accuracy: 0.8866
# Epoch 27/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.2051 - accuracy: 0.9505 - val_loss: 0.8503 - val_accuracy: 0.8910
# Epoch 28/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1901 - accuracy: 0.9506 - val_loss: 1.1321 - val_accuracy: 0.8814
# Epoch 29/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1798 - accuracy: 0.9518 - val_loss: 0.9270 - val_accuracy: 0.8884
# Epoch 30/500
# 375/375 [==============================] - 16s 42ms/step - loss: 0.2404 - accuracy: 0.9532 - val_loss: 0.8159 - val_accuracy: 0.8692
# Epoch 31/500
# 375/375 [==============================] - 16s 43ms/step - loss: 0.1770 - accuracy: 0.9535 - val_loss: 0.8801 - val_accuracy: 0.8833
# Epoch 32/500
# 375/375 [==============================] - 16s 44ms/step - loss: 0.2083 - accuracy: 0.9545 - val_loss: 0.7956 - val_accuracy: 0.8821
# Epoch 33/500
# 375/375 [==============================] - 16s 43ms/step - loss: 0.1929 - accuracy: 0.9553 - val_loss: 0.9206 - val_accuracy: 0.8888
# Epoch 34/500
# 375/375 [==============================] - 16s 41ms/step - loss: 0.1661 - accuracy: 0.9568 - val_loss: 1.2004 - val_accuracy: 0.8867
# Epoch 35/500
# 375/375 [==============================] - 16s 43ms/step - loss: 0.1628 - accuracy: 0.9585 - val_loss: 1.1377 - val_accuracy: 0.8816
# Epoch 36/500
# 375/375 [==============================] - 16s 42ms/step - loss: 0.1568 - accuracy: 0.9608 - val_loss: 1.1140 - val_accuracy: 0.8922
# Epoch 37/500
# 375/375 [==============================] - 16s 43ms/step - loss: 0.1532 - accuracy: 0.9602 - val_loss: 1.1518 - val_accuracy: 0.8921
# Epoch 38/500
# 375/375 [==============================] - 16s 44ms/step - loss: 0.1713 - accuracy: 0.9605 - val_loss: 0.9481 - val_accuracy: 0.8914
# Epoch 39/500
# 375/375 [==============================] - 16s 42ms/step - loss: 0.1523 - accuracy: 0.9623 - val_loss: 0.9544 - val_accuracy: 0.8858
# Epoch 40/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1323 - accuracy: 0.9638 - val_loss: 0.8772 - val_accuracy: 0.8878
# Epoch 41/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1507 - accuracy: 0.9622 - val_loss: 1.4878 - val_accuracy: 0.8799
# Epoch 42/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.1346 - accuracy: 0.9630 - val_loss: 1.1447 - val_accuracy: 0.8892
# Epoch 43/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1455 - accuracy: 0.9636 - val_loss: 1.2841 - val_accuracy: 0.8875
# Epoch 44/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1775 - accuracy: 0.9648 - val_loss: 1.2128 - val_accuracy: 0.8896
# Epoch 45/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1468 - accuracy: 0.9658 - val_loss: 1.1873 - val_accuracy: 0.8901
# Epoch 46/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.1337 - accuracy: 0.9669 - val_loss: 1.2105 - val_accuracy: 0.8910
# Epoch 47/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.1426 - accuracy: 0.9668 - val_loss: 1.1592 - val_accuracy: 0.8914
# Epoch 48/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1437 - accuracy: 0.9681 - val_loss: 1.4650 - val_accuracy: 0.8897
# Epoch 49/500
# 375/375 [==============================] - 16s 44ms/step - loss: 0.2698 - accuracy: 0.9695 - val_loss: 1.1024 - val_accuracy: 0.8945
# Epoch 50/500
# 375/375 [==============================] - 17s 44ms/step - loss: 0.1254 - accuracy: 0.9690 - val_loss: 1.6320 - val_accuracy: 0.8898
# Epoch 51/500
# 375/375 [==============================] - 17s 45ms/step - loss: 0.1219 - accuracy: 0.9684 - val_loss: 1.3116 - val_accuracy: 0.8812
# Epoch 52/500
# 375/375 [==============================] - 17s 46ms/step - loss: 0.1552 - accuracy: 0.9693 - val_loss: 1.1698 - val_accuracy: 0.8905

# %%
# Đánh giá độ chính xác của mô hình sau khi đã train 
Score=model.evaluate(x_test,y_test,verbose=0)
print('Test Loss', Score[0])
print('Test Accuracy', Score[1])
# Out:
# Test Loss 1.4233406782150269
# Test Accuracy 0.8826000094413757

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>
