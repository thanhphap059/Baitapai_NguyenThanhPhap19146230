# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhphap059/NguyenThanhPhap19146230/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
num1=input("Nhap vao so thu 1")
# Out:
# Nhap vao so thu 17

# %%
num2=input(" Nhap vao so thu 2")
# Out:
#  Nhap vao so thu 23

# %%
num=num1+num2

# %%
print(num)
# Out:
# 73

# %%
open with ("test.txt", mode="w") as accounts
# Out:
#   File "<ipython-input-6-2ca22592cc8b>", line 1
#     open with ("test.txt", mode="w") as accounts
#             ^
# SyntaxError: invalid syntax

# %%
With open ("test.txt", mode="W") as accounts:
  accounts.Write("1 Nguyen Van A 8.03\n")
  accounts.Write("2 Le Thi B 6.83\n")
# Out:
#   File "<ipython-input-7-77d3d111271c>", line 1
#     With open ("test.txt", mode="W") as accounts:
#             ^
# SyntaxError: invalid syntax

# %%
with open("test.txt", mode="w") as accounts:
  accounts.write("1 Nguyen Van A 8.03\n")
  accounts.write("2 Le Thi B 6.83\n")
  print("Nguyen Thi C", file=accounts)

# %% [markdown]
# > Văn bản được thụt lề

# %%
with open("test.txt", mode="w") as accounts:
  accounts.write("1 Nguyen Van A 8.03\n")
  accounts.write("2 Le Thi B 6.83\n")
  print("Nguyen Thi C", file=accounts)

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-f070f3ad-ea24-412f-942d-eedd10531409" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f070f3ad-ea24-412f-942d-eedd10531409">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bangdiem.csv to Bangdiem.csv

# %%
import pandas as pd
data=pd.read_csv("test.csv")
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-996c00cf7713> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv("test.csv")
#       3 data.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
data=pd.read_csv(Bangdiem.csv)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-f7cd58bd81b7> in <module>()
#       1 import pandas as pd
# ----> 2 data=pd.read_csv(Bangdiem.csv)
#       3 data
#
# NameError: name 'Bangdiem' is not defined

# %%
data=pd.read_csv(url)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-272bf404e68d> in <module>()
# ----> 1 data=pd.read_csv(url)
#       2 data
#
# NameError: name 'url' is not defined

# %%
data.iloc[0:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-423c4d01e1c7> in <module>()
# ----> 1 data.iloc[0:100]
#
# NameError: name 'data' is not defined

# %%
url="http://winterolympicsmedals.com/medals.csv"
data=pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data.iloc[0:100]
# Out:
#     Year         City       Sport       Discipline  NOC       Event  \
# 0   1924     Chamonix     Skating   Figure skating  AUT  individual
# 1   1924     Chamonix     Skating   Figure skating  AUT  individual
# 2   1924     Chamonix     Skating   Figure skating  AUT       pairs
# 3   1924     Chamonix   Bobsleigh        Bobsleigh  BEL    four-man
# 4   1924     Chamonix  Ice Hockey       Ice Hockey  CAN  ice hockey
# ..   ...          ...         ...              ...  ...         ...
# 95  1932  Lake Placid     Skating    Speed skating  CAN       1500m
# 96  1932  Lake Placid     Skating    Speed skating  CAN       1500m
# 97  1932  Lake Placid     Skating    Speed skating  CAN       5000m
# 98  1932  Lake Placid     Skating    Speed skating  CAN        500m
# 99  1932  Lake Placid      Skiing  Cross Country S  FIN        18km
#
#    Event gender   Medal
# 0             M  Silver
# 1             W    Gold
# 2             X    Gold
# 3             M  Bronze
# ...

# %%
data=data.set_index(data["NOC"])
data.loc["USA"]
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
data[data["NOC"]=="CAN"].head(10)
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# NOC
# CAN  1924                Chamonix  Ice Hockey      Ice Hockey  CAN
# CAN  1928              St. Moritz  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid     Skating  Figure skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  CAN
#
#           Event Event gender   Medal
# NOC
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  individual            M  Bronze
# ...

# %%
data[(data["Year"]=="2002")&(data["NOC"]=="USA")].head(20)
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
data[(data["Medal"]=="Gold")&(data["NOC"]=="FRA")].head(20)
# Out:
#      Year            City     Sport       Discipline  NOC            Event  \
# NOC
# FRA  1928      St. Moritz   Skating   Figure skating  FRA            pairs
# FRA  1932     Lake Placid   Skating   Figure skating  FRA            pairs
# FRA  1948      St. Moritz    Skiing    Alpine Skiing  FRA  alpine combined
# FRA  1948      St. Moritz    Skiing    Alpine Skiing  FRA         downhill
# FRA  1960    Squaw Valley    Skiing    Alpine Skiing  FRA         downhill
# FRA  1964       Innsbruck    Skiing    Alpine Skiing  FRA     giant slalom
# FRA  1964       Innsbruck    Skiing    Alpine Skiing  FRA     giant slalom
# FRA  1964       Innsbruck    Skiing    Alpine Skiing  FRA           slalom
# FRA  1968        Grenoble    Skiing    Alpine Skiing  FRA         downhill
# FRA  1968        Grenoble    Skiing    Alpine Skiing  FRA     giant slalom
# FRA  1968        Grenoble    Skiing    Alpine Skiing  FRA           slalom
# ...

# %%
data["NOC"].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data["NOC"].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data.groupbg(["NOC","Year"])["medals"],count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-91804b177c22> in <module>()
# ----> 1 data.groupbg(["NOC","Year"])["medals"],count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'groupbg'
